# %%
"""Density plots of review counts per user"""

import load
import matplotlib.pyplot as plt

df = load.loadDF(1e10)

"""Group the data by reviewerID and take frequeny
of reviews posted. Plot the density"""
"""
fig, ax = plt.subplots()
freq = df['reviewerID'].value_counts()
freq = freq[freq.between(freq.quantile(.01), freq.quantile(.99))]
freq.plot.kde()
plt.title("Rating per user")
plt.show()
"""
# Out:
# '\nfig, ax = plt.subplots()\nfreq = df[\'reviewerID\'].value_counts()\nfreq = freq[freq.between(freq.quantile(.01), freq.quantile(.99))]\nfreq.plot.kde()\nplt.title("Rating per user")\nplt.show()\n'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1603296 entries, 0 to 1603295
# Data columns (total 13 columns):
# overall           1603296 non-null float64
# verified          1603296 non-null bool
# reviewTime        1603296 non-null object
# reviewerID        1603296 non-null object
# asin              1603296 non-null object
# style             638589 non-null object
# reviewerName      1603099 non-null object
# reviewText        1602219 non-null object
# summary           1602830 non-null object
# unixReviewTime    1603296 non-null int64
# vote              222913 non-null object
# image             32370 non-null object
# category          1603296 non-null object
# dtypes: bool(1), float64(1), int64(1), object(10)
# memory usage: 148.3+ MB

# %%
"""Group the data by reviewerID and take frequeny
of reviews posted. Plot the histograms"""

fig, ax = plt.subplots()
freq = df['overall'].value_counts().sort_index()
freq.plot.bar()
plt.title("Ratings Frequency")
plt.show()

# %%
df['category'].unique()
# Out:
# array(['Software', 'All_Beauty', 'Prime_Pantry', 'Gift_Cards',
#        'Industrial_and_Scientific', 'Arts_Crafts_and_Sewing',
#        'Appliances', 'Luxury_Beauty', 'AMAZON_FASHION'], dtype=object)

# %%
# importing all necessery modules 
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import load
# Reads data files
#df = load.loadDF()


comment_words = '' 
stopwords = set(STOPWORDS) 


# iterate through the csv file 
for val in df[df['category']=='Appliances'].reviewText: 
      
    # typecaste each val to string 
    val = str(val)
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
comment_words.count('thi')
# Out:
# 9378

# %%
# Out:
# '1.18.2'
